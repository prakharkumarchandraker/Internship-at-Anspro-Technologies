# %%
import pandas as pd #Labeling the data
# %matplotlib inline

# %%
df=pd.read_csv('LPG_Data.csv')

# %%
df #Customer_ID = unique id of a customer.
#Member= How many member are using the LPG cylinder.
#LPG_RESULT= Shows after how many days the customer refiills the data

#To show Aproximately how many days will a customer take to order the cylinder again.
# Out:
#      CUSTOMER_ID  MEMBERS LPG_RESULT
# 0              1        2    45 DAYS
# 1              2        2    45 DAYS
# 2              3        2    45 DAYS
# 3              4        2    45 DAYS
# 4              5        2    45 DAYS
# ..           ...      ...        ...
# 175           16       10    10 DAYS
# 176           17       10    10 DAYS
# 177           18       10    10 DAYS
# 178           19       10    10 DAYS
# 179           20       10    10 DAYS
#
# [180 rows x 3 columns]

# %%
df.describe() #Only counts numberical columns.
# Out:
#        CUSTOMER_ID     MEMBERS
# count   180.000000  180.000000
# mean     10.500000    6.000000
# std       5.782366    2.589191
# min       1.000000    2.000000
# 25%       5.750000    4.000000
# 50%      10.500000    6.000000
# 75%      15.250000    8.000000
# max      20.000000   10.000000

# %%
df.info() #Shows type of data and Column details.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CUSTOMER_ID  180 non-null    int64
#  1   MEMBERS      180 non-null    int64
#  2   LPG_RESULT   180 non-null    object
# dtypes: int64(2), object(1)
# memory usage: 4.3+ KB

# %%
import numpy as np

# %%
df.isnull().sum() #Shows there are no missing values.
# Out:
# CUSTOMER_ID    0
# MEMBERS        0
# LPG_RESULT     0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns #Seaborn is a Python data visualization library based on matplotlib.
#It provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
sns.pairplot(df) #Only counts numerical columns. The Seaborn Pairplot allows us to plot pairwise relationships between 
#variables within a dataset. This creates a nice visualisation and helps us understand the data by summarising a large
#amount of data in a single figure. This is essential when we are exploring our dataset and trying to become familiar with it.

# %%
df.columns #Shows all the columns in dataset.
# Out:
# Index(['CUSTOMER_ID', 'MEMBERS', 'LPG_RESULT'], dtype='object')

# %%
sns.displot(df['CUSTOMER_ID'])

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df['CUSTOMER_ID'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CUSTOMER_ID', ylabel='Density'>

# %%
sns.displot(df['CUSTOMER_ID'])

# %%
sns.histplot(df['CUSTOMER_ID'])
# Out:
# <AxesSubplot:xlabel='CUSTOMER_ID', ylabel='Count'>

# %%
sns.distplot(df['MEMBERS'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MEMBERS', ylabel='Density'>
